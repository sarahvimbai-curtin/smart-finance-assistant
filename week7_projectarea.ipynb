# %%
import pandas as pd

df = pd.read_csv("sample_data/transactions (1).csv")

print(df.head())
print(df.describe())

print("Total spent:", df['Amount'].str.replace('$','').astype(float).sum())
print("Average spent:", df['Amount'].str.replace('$','').astype(float).mean())
# Out:
#          Date   Amount       Category                       Description
# 0  2024-08-01   $45.50      Groceries            Woolworths Weekly Shop
# 1  2024-08-02   $12.00      Transport                  Opal Card Top-up
# 2  2024-08-03   $89.95  Entertainment  Concert Tickets - Enmore Theatre
# 3  2024-08-04    $3.50         Coffee            Campus Cafe Flat White
# 4  2024-08-05  $120.00      Groceries                 Coles Weekly Shop
#               Date  Amount Category             Description
# count           20      20       20                      20
# unique          20      20        7                      20
# top     2024-08-01  $45.50   Coffee  Woolworths Weekly Shop
# freq             1       1        5                       1
# Total spent: 873.3
# Average spent: 43.665

# %% [markdown]
# import pandas as pd
#
# df = pd.read_csv("sample_data/transactions (1).csv")
#
# print(df.head())
